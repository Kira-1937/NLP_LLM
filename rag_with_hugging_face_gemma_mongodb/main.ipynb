# %%
# Load Dataset
from datasets import load_dataset
import pandas as pd

# https://huggingface.co/datasets/MongoDB/embedded_movies
dataset = load_dataset("MongoDB/embedded_movies")

# Convert the dataset to a pandas dataframe
dataset_df = pd.DataFrame(dataset["train"])

dataset_df.head(5)
# Out:
#                                             fullplot                  title  \
# 0  Young Pauline is left a lot of money when her ...  The Perils of Pauline
# 1  As a penniless man worries about how he will m...     From Hand to Mouth
# 2  Michael "Beau" Geste leaves England in disgrac...             Beau Geste
# 3  A nobleman vows to avenge the death of his fat...       The Black Pirate
# 4  The Uptown Boy, J. Harold Manners (Lloyd) is a...      For Heaven's Sake
#
#   countries                                     plot_embedding   rated  \
# 0     [USA]  [0.00072939653, -0.026834568, 0.013515796, -0....    None
# 1     [USA]  [-0.022837115, -0.022941574, 0.014937485, -0.0...    TV-G
# 2     [USA]  [0.00023330493, -0.028511643, 0.014653289, -0....    None
# 3     [USA]  [-0.005927917, -0.033394486, 0.0015323418, -0....    None
# 4     [USA]  [-0.0059373598, -0.026604708, -0.0070914757, -...  PASSED
#
#                                               awards  metacritic  \
# ...

# %%
# Data Preparation

# Remove data point where plot coloumn is missing
dataset_df = dataset_df.dropna(subset=["fullplot"])
print("\nNumber of missing values in each column after removal:")
print(dataset_df.isnull().sum())

# Remove the plot_embedding from each data point in the dataset as we are going to create new embeddings with an open source embedding model from Hugging Face
dataset_df = dataset_df.drop(columns=["plot_embedding"])
dataset_df.head(5)
# Out:
# Number of missing values in each column after removal:
# fullplot                0
# title                   0
# countries               0
# plot_embedding          1
# rated                 279
# awards                  0
# metacritic            893
# writers                13
# runtime                14
# poster                 78
# languages               1
# genres                  0
# directors              12
# cast                    1
# plot                    0
# num_mflix_comments      0
# type                    0
# imdb                    0
# dtype: int64
#                                             fullplot                  title  \
# 0  Young Pauline is left a lot of money when her ...  The Perils of Pauline
# 1  As a penniless man worries about how he will m...     From Hand to Mouth
# 2  Michael "Beau" Geste leaves England in disgrac...             Beau Geste
# 3  A nobleman vows to avenge the death of his fat...       The Black Pirate
# ...

# %%
from dotenv import load_dotenv
import os

# Load environment variables from .env file
dotenv_path = '.env'  # Adjust the path to your .env file
load_dotenv(dotenv_path)

# Access environment variables
mongo_uri = os.getenv('MONGO_URI')

# %%
import pymongo
# from google.colab import userdata

def get_mongo_client(mongo_uri):
    """Establish connection to the MongoDB."""
    try:
        client = pymongo.MongoClient(mongo_uri)
        print("Connection to MongoDB successful")
        return client
    except pymongo.errors.ConnectionFailure as e:
        print(f"Connection failed: {e}")
        return None


if not mongo_uri:
    print("MONGO_URI not set in environment variables")

mongo_client = get_mongo_client(mongo_uri)

# Ingest data into MongoDB
db = mongo_client["movies"]
collection = db["movies_colllection1"]
# Out:
# Connection to MongoDB successful

# %%
documents = dataset_df.to_dict('records')
collection.insert_many(documents)
print("Data ingestion into MongoDB completed")
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# Cell In[21], line 2
#       1 documents = dataset_df.to_dict('records')
# ----> 2 collection.insert_many(documents)
#       3 print("Data ingestion into MongoDB completed")
#
# File c:\Users\Dell\anaconda3\envs\RAG_WITH_HUGGING_FACE_GEMMA_MONGODB\Lib\site-packages\pymongo\_csot.py:107, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     105         with _TimeoutContext(timeout):
#     106             return func(self, *args, **kwargs)
# --> 107 return func(self, *args, **kwargs)
#
# File c:\Users\Dell\anaconda3\envs\RAG_WITH_HUGGING_FACE_GEMMA_MONGODB\Lib\site-packages\pymongo\collection.py:755, in Collection.insert_many(self, documents, ordered, bypass_document_validation, session, comment)
#     753 blk = _Bulk(self, ordered, bypass_document_validation, comment=comment)
#     754 blk.ops = list(gen())
# ...

# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi
# uri = "mongodb+srv://vikramaryasaharan:20312040@cluster0.awz3rqy.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"
uri="mongodb+srv://testuser:testuser1@cluster0.ci6my0a.mongodb.net/"
# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))
# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# SSL handshake failed: ac-3bqrcih-shard-00-00.ci6my0a.mongodb.net:27017: [SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1000) (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms),SSL handshake failed: ac-3bqrcih-shard-00-02.ci6my0a.mongodb.net:27017: [SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1000) (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms),SSL handshake failed: ac-3bqrcih-shard-00-01.ci6my0a.mongodb.net:27017: [SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1000) (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms), Timeout: 30s, Topology Description: <TopologyDescription id: 661411a86fb7f7ab17ea2691, topology_type: ReplicaSetNoPrimary, servers: [<ServerDescription ('ac-3bqrcih-shard-00-00.ci6my0a.mongodb.net', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('SSL handshake failed: ac-3bqrcih-shard-00-00.ci6my0a.mongod
# ...

# %%
from pymongo import MongoClient

# Update connection string with your new password
connection_string = "mongodb+srv://testuser:testuser1@cluster0.ci6my0a.mongodb.net/"

try:
    # Attempt to connect to MongoDB Atlas cluster
    client = MongoClient(connection_string)

    # Access database and collection
    db = client.get_database('Vector_db')
    collection = db.get_collection('movies')
    print(collection)

    # Print all documents in the collection
    
    
    for document in collection.find():
        print(document)

    # Close connection
    client.close()

except Exception as e:
    print("Error:", e)
# Out:
# Collection(Database(MongoClient(host=['ac-3bqrcih-shard-00-00.ci6my0a.mongodb.net:27017', 'ac-3bqrcih-shard-00-02.ci6my0a.mongodb.net:27017', 'ac-3bqrcih-shard-00-01.ci6my0a.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, authsource='admin', replicaset='atlas-mpm9ph-shard-0', tls=True), 'Vector_db'), 'movies')
# ...
